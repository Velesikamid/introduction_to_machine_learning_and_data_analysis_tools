# %% [markdown]
# <p><span
#     style="font-family: verdana, arial, helvetica, sans-serif;"><strong><span
#         style="color: #000080;">Практическое задание:</span></strong> построение
#     графиков с помощью библиотеки <strong><span
#         style="color: #333399;">Matplotlib.</span></strong></span></p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">Файл с
#     данными <a
#       style="font-family: verdana, arial, helvetica, sans-serif; font-size: large; background-color: #ffffff;"
#       href="https://drive.google.com/file/d/1UROD2g-L84LfC7aYGUyrLO7UsxnAyp62/view?usp=sharing">creditcard.csv</a> (нажмите
#     скачать)</span></p>
# <p><span
#     style="font-family: verdana, arial, helvetica, sans-serif;"><strong><span
#         style="color: #333399;">Задание 1.</span></strong></span></p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">Загрузите
#     модуль <strong><span style="color: #000080;">pyplot</span></strong>
#     библиотеки <strong><span style="color: #000080;">M</span><span
#         style="color: #000080;">atplotlib</span></strong> с псевдонимом <span
#       style="color: #000080;">plt</span>, а также библиотеку <strong><span
#         style="color: #000080;">Numpy</span></strong> с псевдонимом <span
#       style="color: #000080;">np</span>. </span><br><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">Примените
#     магическую функцию <span style="color: #000080;">%matplotlib inline</span>
#     для отображения графиков в Jupyter Notebook и настройки конфигурации
#     ноутбука со значением 'svg' для более четкого отображения графиков. </span>
# </p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">Постройте
#     линейный график с помощью функции <span style="color: #000080;">plot</span>,
#     отображающий зависимость квадрата числа от самого числа на интервале от -10
#     до 10.</span></p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;"><strong
#       style="color: #333399; font-size: 1rem;">Задание 2.</strong></span></p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">Постройте
#     на одном графике синусоиду и косинусоиду от 0 до </span></p>
# <math style="display: block">
#   <semantics>
#     <mrow>
#       <mn>2</mn>
#       <mi>π</mi>
#     </mrow>
#     <annotation encoding="application/x-tex">2\pi</annotation>
#   </semantics>
# </math>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">.
#     Используйте разные цвета и стили линий для их отображения. С помощью функции
#     <span style="color: #000080;">linspace</span> из библиотеки <strong><span
#         style="color: #000080;">Numpy</span></strong> создайте массив <em>t</em>
#     из 51 числа от 0 до 10 включительно.</span><br><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">Создайте массив
#     <strong><span style="color: #000080;">Numpy</span></strong> под названием
#     <span style="color: #333333;"><em>f</em></span>, содержащий косинусы и
#     синусы элементов массива <em>t</em>.</span><br><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">Постройте
#     линейную диаграмму, используя массив <em>t</em> для координат по
#     горизонтали, а массив <em>f</em> - для координат по вертикали. Определите
#     для линии данного графика зеленый цвет.</span><br><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">Выведите
#     название диаграммы - 'График f(t)'.</span><br><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">Также добавьте
#     названия для горизонтальной оси - 'Значения t' и для вертикальной -
#     'Значения f'.</span><br><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">Ограничьте
#     график по оси <em>x</em> значениями 0.5 и 9.5, а по оси <em>y</em> -
#     значениями -2.5 и 2.5.</span></p>
# <p><span
#     style="font-family: verdana, arial, helvetica, sans-serif;"><strong><span
#         style="color: #333399;">Задание 3.</span></strong></span></p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">С помощью
#     функции <span style="color: #000080;">linspace</span> библиотеки
#     <strong><span style="color: #000080;">Numpy</span></strong> создайте массив
#     <em>x</em> из 51 числа от -3 до 3 </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">включительно.</span>
# </p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">Постройте
#     два графика: на первом графике покажите экспоненциальную функцию </span></p>
# <math style="display: block">
#   <semantics>
#     <mrow>
#       <mi>y</mi>
#       <mo>=</mo>
#       <msup>
#         <mi>e</mi>
#         <mi>x</mi>
#       </msup>
#     </mrow>
#     <annotation encoding="application/x-tex">y = e^x</annotation>
#   </semantics>
# </math>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">, на втором
#     — натуральный логарифм </span></p>
# <math style="display: block">
#   <semantics>
#     <mrow>
#       <mi>y</mi>
#       <mo>=</mo>
#       <mi>ln</mi>
#       <mo>⁡</mo>
#       <mo stretchy="false">(</mo>
#       <mi>x</mi>
#       <mo stretchy="false">)</mo>
#     </mrow>
#     <annotation encoding="application/x-tex">y = \ln(x)</annotation>
#   </semantics>
# </math>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">.</span>
# </p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">Используя
#     функцию <span style="color: #000080;">subplots</span> модуля <strong
#       style="font-family: verdana, arial, helvetica, sans-serif; font-size: large;"><span
#         style="color: #000080;">matplotlib.pyplot</span></strong>, создайте
#     объект matplotlib.figure.Figure с </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">названием
#     <em>fig</em> и массив объектов <strong><span
#         style="color: #000080;">Axes</span></strong> под названием <em>ax</em>,
#     причем так, чтобы было 2 отдельных </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">графика в сетке,
#     состоящей из одной строки и двух столбцов. В каждом графике массив
#     <em>x</em> используется для координат по горизонтали. </span></p>
# <p><span
#     style="color: #333399; font-family: verdana, arial, helvetica, sans-serif;"><strong>Задание
#       4.</strong></span></p>
# <p></p>
# <p dir="ltr"><span
#     style="font-size: large; font-family: verdana, arial, helvetica, sans-serif;">В
#     датафрейме ниже представлены результаты соревнований: для каждого игрока
#     указано  набранное количество очков в нескольких попытках.</span></p>
# <p></p>
# <p dir="ltr"><span
#     style="font-size: large; font-family: verdana, arial, helvetica, sans-serif;">data
#     = {</span></p>
# <p></p>
# <p dir="ltr"><span
#     style="font-size: large; font-family: verdana, arial, helvetica, sans-serif;">    'Name':
#     ['Анна', 'Антон', 'Мария', 'Макс', 'Макс', 'Алекс', 'Антон', 'Мария',
#     'Макс', 'Алекс', 'Антон', 'Анна'],</span></p>
# <p></p>
# <p dir="ltr"><span
#     style="font-size: large; font-family: verdana, arial, helvetica, sans-serif;">     'Points':
#     [145, 2524, 343, 4212, 5212, 6421, 745, 842, 524, 3224, 212,
#     1214]      </span></p>
# <p></p>
# <p dir="ltr"><span
#     style="font-size: large; font-family: verdana, arial, helvetica, sans-serif;">}</span>
# </p>
# <p></p>
# <p dir="ltr"><span
#     style="font-size: large; font-family: verdana, arial, helvetica, sans-serif;">Создайте
#     из этих данных датафрейм. Сгруппируйте данные по имени игроков. Методом
#     plot() для датафреймов постройте график минимальных, максимальных и средних
#     очков каждого игрока на одной системе координат.</span></p>
# <p dir="ltr"><span style="color: #333399;"><strong><span
#         style="font-size: large; font-family: verdana, arial, helvetica, sans-serif;">Задание
#         5.</span></strong></span></p>
# <p></p>
# <p><span
#     style="color: #000000; font-family: verdana, arial, helvetica, sans-serif;">Создайте
#     круговую диаграмму, отображающую доли различных категорий (например,
#     фруктов: яблоки, бананы, апельсины, виноград).</span></p>
# <div class="alert alert-primary" role="alert">
#   <p><span style="font-family: verdana, arial, helvetica, sans-serif;">labels =
#       [<span class="hljs-string">'Apples'</span>, <span
#         class="hljs-string">'Bananas'</span>, <span
#         class="hljs-string">'Oranges'</span>, <span
#         class="hljs-string">'Grapes'</span>]</span></p>
#   <p><span style="font-family: verdana, arial, helvetica, sans-serif;">sizes =
#       [<span class="hljs-number">25</span>, <span
#         class="hljs-number">35</span>, <span
#         class="hljs-number">20</span>, <span
#         class="hljs-number">20</span>]</span></p>
#   <p><span style="font-family: verdana, arial, helvetica, sans-serif;">colors =
#       [<span class="hljs-string">'red'</span>, <span
#         class="hljs-string">'yellow'</span>, <span
#         class="hljs-string">'orange'</span>, <span
#         class="hljs-string">'purple'</span>]</span></p>
#   <p><span style="font-family: verdana, arial, helvetica, sans-serif;">explode =
#       (<span class="hljs-number">0.1</span>, <span
#         class="hljs-number">0</span>, <span class="hljs-number">0</span>, <span
#         class="hljs-number">0</span>) <span class="hljs-comment"># выделить
#         сектор с яблоками</span></span></p>
# </div>
# <p></p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;"><strong
#       style="font-size: 1rem;"><span style="color: #333399;">Задание
#         6.</span></strong></span></p>
# <p><span
#     style="font-size: medium; font-family: verdana, arial, helvetica, sans-serif;">Создайте
#     вертикальную столбчатую диаграмму, показывающую количество товаров,
#     проданных в пяти разных магазинах.</span></p>
# <div class="alert alert-primary" role="alert">
#   <p><span style="font-family: verdana, arial, helvetica, sans-serif;">stores =
#       ['Store A', 'Store B', 'Store C', 'Store D', 'Store E']</span><br><span
#       style="font-family: verdana, arial, helvetica, sans-serif;">sales = [50,
#       80, 60, 70, 90]</span></p>
# </div>
# <p></p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;"><strong
#       style="font-size: 1rem;"><span style="color: #333399;">Задание
#         7.</span></strong></span></p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">Рассмотрим
#     датасет, который содержит информацию об случаях мошенничества с </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">кредитными
#     данными: Credit Card Fraud Detection (информация об авторах: Andrea Dal
#     Pozzolo, Olivier </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">Caelen, Reid A.
#     Johnson and Gianluca Bontempi. Calibrating Probability with Undersampling
#     for Unbalanced </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">Classification.
#     In Symposium on Computational Intelligence and Data Mining (CIDM), IEEE,
#     2015).</span></p>
# <p><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">Ознакомьтесь с
#     описанием и скачайте датасет <a
#       style="font-family: verdana, arial, helvetica, sans-serif; font-size: large; background-color: #ffffff;"
#       href="https://drive.google.com/file/d/1UROD2g-L84LfC7aYGUyrLO7UsxnAyp62/view?usp=sharing">creditcard.csv</a> с
#     сайта Kaggle.com по ссылке:  </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">[Credit Card
#     Fraud
#     Detection](https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud)</span>
# </p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">Данный
#     датасет является примером несбалансированных данных, так как мошеннические
#     операции с </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">картами
#     встречаются реже обычных.</span></p>
# <p><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">Импортируйте
#     библиотеку <strong><span style="color: #000080;">Pandas</span></strong>, а
#     также используйте для графиков стиль “fivethirtyeight”.</span></p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">Постройте
#     гистограмму, отображающую распределение транзакций по времени (по столбцу
#     <code>Time</code>). Используйте 50 bin- ов  и добавьте сетку на
#     график.</span></p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">Посчитайте
#     с помощью метода <span style="color: #000080;">value_counts</span>
#     количество наблюдений для каждого значения целевой </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">переменной
#     <em><span style="color: #000080;">Class</span></em> и примените к полученным
#     данным метод <strong><span style="color: #000080;">plot</span></strong>,
#     чтобы построить столбчатую </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">диаграмму. Затем
#     постройте такую же диаграмму, используя логарифмический масштаб.</span></p>
# <p><span style="font-family: verdana, arial, helvetica, sans-serif;">На
#     следующем графике постройте две гистограммы по значениям признака V1 - одну
#     для </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">мошеннических
#     транзакций (<span style="color: #000080;"><em>Class</em></span> равен 1) и
#     другую - для обычных (<em><span style="color: #000080;">Class</span></em>
#     равен 0). Подберите </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">значение
#     аргумента <span style="color: #000080;">density</span> так, чтобы по
#     вертикали графика было расположено не число </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">наблюдений, а
#     плотность распределения. Число бинов должно равняться 20 для обеих
#     гистограмм, а </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">коэффициент
#     <span style="color: #000080;">alpha</span> примите равным 0.5, чтобы
#     гистограммы были полупрозрачными и не </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">загораживали
#     друг друга. Создайте легенду с двумя значениями: “Class 0” и “Class 1”.
#     Гистограмма </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">обычных
#     транзакций должна быть серого цвета, а мошеннических - красного.
#     Горизонтальной оси </span><span
#     style="font-family: verdana, arial, helvetica, sans-serif;">дайте название
#     “V1”.</span></p>
# <p><span
#     style="font-size: medium; font-family: verdana, arial, helvetica, sans-serif;">Постройте
#     круговую диаграмму, отображающую доли мошеннических  (<span
#       style="color: #000080;"><em>Class</em></span> равен 1) и обычных
#     транзакций (<span style="color: #000080;"><em>Class</em></span> равен
#     0).</span></p>
# <p></p>
# <p></p>

# %% [markdown]
# <p><span
#     style="color: #333399; font-size: medium; font-family: verdana, arial, helvetica, sans-serif;"><strong>Практическое
#       задание: </strong><span style="color: #333333;">использования библиотеки
#       <strong><span style="color: #000080;">Seaborn</span></strong> для создания
#       наглядных и информативных визуализаций.</span></span></p>
# <p></p>
# <p><span
#     style="color: #333399; font-size: medium; font-family: verdana, arial, helvetica, sans-serif;"><strong>Задание
#       1.</strong></span></p>
# <ul>
#   <li><span
#       style="font-family: verdana, arial, helvetica, sans-serif;">Используйте
#       набор данных <code>tips</code> из библиотеки <strong><span
#           style="color: #000080;">Seaborn</span></strong>. Постройте график
#       распределения (<code>distplot</code>), который показывает распределение
#       переменной <code>total_bill</code>. Добавьте кривую плотности
#       распределения (KDE).</span>
#     <div class="alert alert-primary" role="alert"><span
#         style="font-family: verdana, arial, helvetica, sans-serif;"><span
#           class="hljs-keyword">import</span> seaborn <span
#           class="hljs-keyword">as</span> sns </span><br><span
#         style="font-family: verdana, arial, helvetica, sans-serif;"><span
#           class="hljs-keyword">import </span>matplotlib.pyplot <span
#           class="hljs-keyword">as</span> plt </span><br><span
#         style="font-family: verdana, arial, helvetica, sans-serif;">tips =
#         sns.load_dataset(<span class="hljs-string">'tips'</span>)</span></div>
#   </li>
#   <li><span
#       style="font-family: verdana, arial, helvetica, sans-serif;">Постройте
#       диаграмму рассеяния (<code>scatterplot</code>), показывающую зависимость
#       между переменными <code>total_bill</code> и <code>tip</code>. Раскрасьте
#       точки соответственно пола клиента (<code>sex</code>) и добавьте
#       регрессионную линию.</span></li>
#   <li><span
#       style="font-family: verdana, arial, helvetica, sans-serif;">Постройте
#       диаграмму типа "ящик с усами" (<span
#         style="color: #333399;"><code>boxplot</code></span>), которая показывает
#       распределение переменной <code>total_bill</code> в зависимости от дня
#       недели (<code>day</code>). Используйте различную цветовую палитру для
#       каждого дня.</span></li>
#   <li>Создайте сетку графиков с помощью <code>FacetGrid</code>, отображающую
#     зависимость между переменными <code>total_bill</code> и <code>tip</code> в
#     наборе данных <code>tips</code> с разбивкой по времени суток
#     (<code>time</code>) и полу пассажира (<code>sex</code>). Внутри каждого
#     графика постройте регрессионную линию.</li>
# </ul>
# <p><span style="color: #333399;"><strong>Задание 2</strong></span></p>
# <ul>
#   <li><span
#       style="font-family: verdana, arial, helvetica, sans-serif;">Постройте
#       диаграмму парных зависимостей (<code>pairplot</code>) для набора данных
#       <code>iris</code>, раскрасьте точки по виду цветка
#       (<code>species</code>).</span></li>
# </ul>
# <p><span
#     style="font-family: verdana, arial, helvetica, sans-serif;"><strong><span
#         style="color: #333399;">Задание 3</span></strong></span></p>
# <ul>
#   <li><span
#       style="font-family: verdana, arial, helvetica, sans-serif;">Используйте
#       набор данных <code>titanic</code> из библиотеки <strong><span
#           style="color: #000080;">Seaborn</span></strong>. <br></span></li>
#   <li><span
#       style="font-family: verdana, arial, helvetica, sans-serif;">Используйте
#       данные по корреляции признаков из набора данных <code>titanic</code>,
#       чтобы построить тепловую карту (heatmap), которая показывает взаимосвязь
#       между различными переменными. Добавьте аннотации (значения корреляций) на
#       тепловую карту.</span></li>
#   <li><span
#       style="font-family: verdana, arial, helvetica, sans-serif;">Постройте
#       KDE-график, показывающий распределение переменной <code>fare</code> из
#       набора данных <code>titanic</code>, и отобразите это распределение
#       отдельно для каждого класса пассажиров (<code>class</code>).</span></li>
#   <li><span
#       style="font-family: verdana, arial, helvetica, sans-serif;">Используйте
#       метод <code>lmplot</code>, чтобы построить диаграмму, показывающую
#       зависимость между переменными <code>age</code> и <code>fare</code> для
#       пассажиров Титаника, с разбивкой по полу (<code>sex</code>) и классу
#       обслуживания (<code>class</code>). Добавьте регрессионную линию.</span>
#   </li>
# </ul>
